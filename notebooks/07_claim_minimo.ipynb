# %% [markdown]
# # Congelamento do Claim Mínimo
#
# **Objetivo:** Consolidar formalmente o fechamento do núcleo mínimo sem introduzir novas derivações.
#
# **Tag Epistemológica:** DERIVADO + CONDICIONAL
#
# **Definição:** Este notebook apenas organiza os resultados obtidos nos notebooks anteriores e explicita as condições sob as quais o fechamento nulo-local é válido.

# %%
# Estrutura formal do claim mínimo (sem cálculo novo)

claim = {
    "domain": "diamante causal local",
    "functional": "S_gen = A/(4Għ) + S_edge",
    "operator": "d²S_gen/dλ² projetado por k^μ k^ν",
    "modular_bridge": "δS_edge = k_B δ⟨K_R⟩ (1ª ordem)",
    "geometric_result": "G_{μν} k^μ k^ν = (8πG/c^4) ⟨T_{μν}⟩ k^μ k^ν",
    "validity": [
        "regime local",
        "estado de referência bem definido",
        "expansão de primeira ordem",
        "hipóteses explícitas do esquema algébrico"
    ]
}

claim

# %% [markdown]
# ## Registro de Resultados
#
# O núcleo mínimo é formalmente fechado na forma de projeção nulo-local da equação de Einstein.
#
# Este resultado:
#
# * não constitui a equação completa em todos os componentes;
# * depende explicitamente das hipóteses da primeira lei e do regime local;
# * não incorpora completamentos como setor escalar-tensorial ou hipóteses UV.
