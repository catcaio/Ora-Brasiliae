# %% [markdown]
# # Veredito do Claim Mínimo
#
# - **Status:** PLACEHOLDER
# - **Categoria Epistemológica:** DERIVADO + CONDICIONAL
# - **Pertence ao CORE?** Sim
# - **Objetivo:** Sumarizar os resultados auditados e congelar o veredito.
# - **Dependências:** `01` a `06`
# - **Restrições editoriais:** O output final deve ser estrito ao claim irredutível.
# - **Próximos passos:** Povoar com as chamadas de verificação final e dump do dicionário.
