# %% [markdown]
# # Bianchi e $\phi(x)$
#
# - **Status:** PLACEHOLDER
# - **Categoria Epistemológica:** COMPLETAMENTO CONSISTENTE
# - **Pertence ao CORE?** Não
# - **Objetivo:** Auditar o termo corretivo na identidade de Bianchi.
# - **Dependências:** `01`, `02`, `03`
# - **Restrições editoriais:** Não usar como canonicidade forte.
# - **Próximos passos:** Povoar com o cálculo de J_{mu nu}.
