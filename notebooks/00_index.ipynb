# %% [markdown]
# # Teoria de Ora Brasiliae: Auditoria Simbólica
#
# ## Escopo do Repositório
# Este diretório contém a infraestrutura de auditoria simbólica e numérica reprodutível do programa local baseado em entropia generalizada em diamantes causais.
#
# ## Fluxo Lógico
# `core` -> `gaps` -> `appendices`
#
# ## Convenções de Notação
# - Métricas e tensores no regime local.
# - `k` e `L` como vetores nulos conjugados.
# - Assinatura da métrica: `(-, +, +, +)`.
#
# ## Índice de Notebooks
# | Notebook | Título / Objetivo | Dependências |
# | :--- | :--- | :--- |
# | `01_domain_and_definitions.ipynb` | Definir domínio geométrico, base nula, e $S_{gen}$ | Nenhuma |
# | `02_variational_operator.ipynb` | Operador variacional projetado | `01` |
# | `03_modular_first_law.ipynb` | Primeira lei modular em 1ª ordem | `01`, `02` |
# | `04_gap10_symbolic.ipynb` | GAP-10 | `01` |
# | `05_bianchi_and_phi.ipynb` | Identidade de Bianchi e $\phi$ | `01`, `02`, `03` |
# | `06_newtonian_limit.ipynb` | Limite Newtoniano | `05` |
# | `07_claim_minimo.ipynb` | Veredito final do núcleo mínimo | `01` a `06` |
# | `08_gap10_numeric_scan.ipynb` | Varredura numérica do GAP-10 | `04` |
# | `09_newtonian_parameter_scan.ipynb` | Sensibilidade paramétrica no limite Newtoniano | `06` |
# | `10_visibility_prediction_scan.ipynb` | Predição de visibilidade por regime | `09` |
# | `11_nstar_threshold_exploration.ipynb` | Exploração de fronteira $N^*$ | `10` |
# | `12_physical_parameter_calibration.ipynb` | Calibração física de parâmetros $(a,b)$ | `10`, `11` |
# | `13_scaling_stability_test.ipynb` | Estabilidade do escalonamento | `10` a `12` |
# | `14_model_discrimination_metric.ipynb` | Métrica de discriminação entre modelos | `10` a `13` |
# | `15_physical_system_mapping.ipynb` | Mapeamento para plataformas físicas | `12`, `14` |
# | `16_signal_vs_noise_analysis.ipynb` | Robustez de sinal vs ruído | `10` a `15` |
# | `17_experimental_window_estimation.ipynb` | Janela operacional de detectabilidade | `15`, `16` |
# | `18_measurement_simulation.ipynb` | Simular coleta com erro e avaliar distinguibilidade operacional | `17` |
